# %% [markdown]
# <a href="https://colab.research.google.com/github/MahimOTG/NASA-API-DATA/blob/main/reading_csv_from_web.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from io import stringIO

url=""
headers={"user-Agent":"Mozilla/5.0(Macintosh;Intel Mac OS X 10.14;rv:66.0) Gecko/"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
